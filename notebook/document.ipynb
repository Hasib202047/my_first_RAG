# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content = "this is the main text content I am using to create RAG",
    metadata = {
        "source" : "example.txt",
        "pages": 1,
        "author": "Hasib",
        "date_created": "2026-10-07"

    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Hasib', 'date_created': '2026-10-07'}, page_content='this is the main text content I am using to create RAG')

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import DirectoryLoader

dir_loader = DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls= TextLoader,
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False
)

document = dir_loader.load()
document
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.'),
#  Document(metadata={'source': '../data/text_files/machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    ')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader
dir_loader = DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls= PyMuPDFLoader,
    show_progress=False
)

document = dir_loader.load()
document
# Out:
# [Document(metadata={'producer': 'macOS Version 26.5.1 (Build 25F80) Quartz PDFContext', 'creator': '', 'creationdate': "D:20260711165750Z00'00'", 'source': '../data/pdf/Sanjana_SOP_UWA_MIT_v4.pdf', 'file_path': '../data/pdf/Sanjana_SOP_UWA_MIT_v4.pdf', 'total_pages': 7, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20260711165750Z00'00'", 'trapped': '', 'modDate': "D:20260711165750Z00'00'", 'creationDate': "D:20260711165750Z00'00'", 'page': 0}, page_content='To, \nThe Visa Officer, \nEmbassy of Australia, \nDhaka, Bangladesh \nSubject: Application for Student Visa (Subclass 500) Master of Information Technology \n(62510), University of Western Australia, Perth, Western Australia \nDear Visa Officer, \nMy name is Sanjana Akter Roshni, and I am a Bangladeshi citizen (Passport No: A21053837). \nI am writing to apply for a Student Visa (Subclass 500) for the Master of Information \nTechnology (course code 62510) at the University of Western Australia (UWA), Perth, \nWestern Australia. I have a BSc in Computer Science and Engineering from Ahsanullah \nUniversity of Science and Technology (AUST), which I completed in 2023, and I have been \nworking as a Full Stack Developer since May 2024.  \nI live at 324/A, East Rampura, Dhaka with my husband Hasibul Hoque. We got married on 11 \nAugust 2023 and he will travel to Australia as my dependent. \nAcademic Background \nI completed my BSc in Computer Science and Engineering at Ahsanullah University of Science \nand Technology (AUST) in Dhaka, enrolling in 2019 and graduating in 2023. Over those four \nyears, I studied subjects like programming, data structure and algorithms, database systems, \nsoftware engineering, networking, and systems analysis. These gave me a strong base in \ncomputing fundamentals, and I still rely on much of what I learned there in my current job. \nThe program gave me a strong foundation in core computing concepts, but it mainly focused \non theoretical learning. Software engineering was taught only as a single introductory subject, \nwithout covering advanced topics like agile methods, requirements engineering, or software \nquality assurance in depth. Networking and systems were also taught at a basic undergraduate \nlevel. Databases mainly covered SQL and relational database concepts, without exploring areas \nlike cloud databases, or high-performance query processing.  \nThe Master of Information Technology at UWA feels like a genuine academic progression \nrather than just repeating my past studies because its curriculum directly targets these gaps \nacross three distinct areas:'),
#  Document(metadata={'producer': 'macOS Version 26.5.1 (Build 25F80) Quartz PDFContext', 'creator': '', 'creationdate': "D:20260711165750Z00'00'", 'source': '../data/pdf/Sanjana_SOP_UWA_MIT_v4.pdf', 'file_path': '../data/pdf/Sanjana_SOP_UWA_MIT_v4.pdf', 'total_pages': 7, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20260711165750Z00'00'", 'trapped': '', 'modDate': "D:20260711165750Z00'00'", 'creationDate': "D:20260711165750Z00'00'", 'page': 1}, page_content="• \nSoftware Systems: To transition from basic coding to enterprise design, I need a \nrigorous framework for building reliable applications. Units like Software \nRequirements and Design (CITS4401), Software Testing and Quality Assurance \n(CITS5501), and Agile Web Development (CITS5505) will give me the structured \nengineering methodologies I currently lack in my day-to-day delivery processes.  \n• \nApplied Computing: Since I deal with transactional systems every day, understanding \ninfrastructure is critical. This stream plugs a major gap in my profile by offering formal \ntraining in Cloud Computing (CITS5503), Open-Source Tools and Scripting \n(CITS4407)- areas I navigate purely by trial and error right now.  \n• \nArtificial Intelligence: To prepare for the future of intelligent automation in enterprise \nplatforms, I need to move beyond fixed business rules. Mastering Machine Learning \n(CITS5508), Natural Language Processing (CITS4012), and Artificial Intelligence and \nAdaptive Systems (CITS4404) will give me the technical capability to build smart, \ndata-driven systems.  \nFinally, the IT Capstone Project (CITS5206) ties all three of these streams together through \napplied, hands-on research. This is a level of practical execution that my undergraduate \nprogram simply didn't offer, and it is exactly the bridge I need to transition from writing code \nas a developer to designing large-scale enterprise architecture. \n \nProfessional Experience \nSince May 2024, I have been working as a Programmer (Full Stack Developer) at Computer \nEase Limited in Dhaka. My day-to-day work involves building enterprise software for \nfinancial and transactional systems. I regularly use C#, .NET Framework, SQL Server, and \nAngular. On the backend, I write REST APIs, build payment processing services, and develop \ntransaction validation systems. I have also integrated third-party APIs, including bKash and \nSMS gateways into our platforms. On the frontend, I work with Angular and Kendo UI to \nbuild data dashboards and user interfaces. \nSo far, I have contributed to several major systems, including an EFT Payment System \n(National Exchange Money Transfer), an Enterprise Sales and Reporting System (Orion Sales), \nand an Operational Dashboard and Visit Planning System. These projects exposed me to the"),
#  Document(metadata={'producer': 'macOS Version 26.5.1 (Build 25F80) Quartz PDFContext', 'creator': '', 'creationdate': "D:20260711165750Z00'00'", 'source': '../data/pdf/Sanjana_SOP_UWA_MIT_v4.pdf', 'file_path': '../data/pdf/Sanjana_SOP_UWA_MIT_v4.pdf', 'total_pages': 7, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20260711165750Z00'00'", 'trapped': '', 'modDate': "D:20260711165750Z00'00'", 'creationDate': "D:20260711165750Z00'00'", 'page': 2}, page_content='practical realities of enterprise software development, particularly in environments where \nsecurity, reliability, reporting accuracy, and high transaction volumes are essential. \nWhile this experience has strengthened my development skills, it has also shown me the \nlimitations of my current technical knowledge. For example, I regularly work with systems \ndeployed across cloud and network environments, yet I have never formally studied cloud \narchitecture, distributed infrastructure, or deployment engineering. Similarly, although I \nparticipate in software delivery processes every day, I lack formal training in advanced \nsoftware quality practices, scalable system design, and structured project engineering \nmethodologies. \nAnother area that increasingly interests me is intelligent automation. Many of the systems I \ncurrently work on still rely heavily on fixed business rules and manual decision flows. Through \nworking with transactional and financial data, I have realized how technologies such as \nmachine learning and intelligent pattern analysis can improve fraud detection, operational \nefficiency, and automated decision-making within enterprise platforms. \nThese professional experiences are the primary reason I am pursuing higher education now. I \ndo not want to remain limited to application-level coding alone. I want to develop the ability \nto design, manage, and improve enterprise systems at a deeper architectural and strategic level. \n \nWhy Australia and the University of Western Australia \nBefore applying, I looked at the UK, Canada, and Australia as possible study destinations. The \nUK has good universities, but they offer one-year master’s programs, which do not provide \nenough time to gain practical knowledge. Canada was another option I considered, but recent \nchanges to their study permit policies have created a lot of uncertainty for international \nstudents, and I was not comfortable with that risk. Australia felt like the most stable and \npractical choice. It has a clear student visa process, ACS-accredited IT programs, and post-\nstudy work rights through the Temporary Graduate (Subclass 485) visa, which is an important \nfactor for someone in the IT field. \nI chose Perth over Sydney and Melbourne because it is more affordable. According to \nNumbeo’s 2024 data, Perth is roughly 15 to 20 percent cheaper in terms of rent, transport, and'),
#  Document(metadata={'producer': 'macOS Version 26.5.1 (Build 25F80) Quartz PDFContext', 'creator': '', 'creationdate': "D:20260711165750Z00'00'", 'source': '../data/pdf/Sanjana_SOP_UWA_MIT_v4.pdf', 'file_path': '../data/pdf/Sanjana_SOP_UWA_MIT_v4.pdf', 'total_pages': 7, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20260711165750Z00'00'", 'trapped': '', 'modDate': "D:20260711165750Z00'00'", 'creationDate': "D:20260711165750Z00'00'", 'page': 3}, page_content="everyday costs. I plan to share an apartment near the campus for around AUD 200-350 per \nweek and travel to UWA via the Claremont or Daglish train stations on the Fremantle Line.  \nBefore choosing The University of Western Australia (UWA), I carefully evaluated the \npostgraduate information technology options across all major universities in Perth. While each \ninstitution possesses distinct strengths, a direct comparison of their curriculum depth, global \nacademic standings, and long-term career alignment confirmed that UWA was the ideal fit for \nmy future career. \n• Murdoch University: While its IT programs offer solid, broad practical exposure, a \nclose inspection of the curriculum revealed it lacked the advanced technical depth and \nresearch intensity required for the direction I want to pursue. \n• Curtin University: Despite its strong reputation in applied technology, its master’s \nofferings—particularly the Master of Information Systems and Technology—lean \nheavily toward business-oriented IT transformation, data management, and \ngovernance. It lacks the balanced focus on advanced software architecture and artificial \nintelligence that I need. \n• Edith Cowan University (ECU): While highly accessible and focused on general \nprofessional preparation, the coursework is tailored more toward foundational IT \ntraining rather than the highly specialized, research-backed engineering environment \nexpected at the postgraduate level. \nBeyond the curriculum, university standing was a major factor for me. UWA consistently ranks \nin the global Top 100 (sitting at #77 in the QS World Rankings), which puts it a step ahead of \nCurtin (Top 200), Murdoch (Top 500), and ECU (Top 600). Being a Group of Eight institution \nmeans UWA provides a level of research culture, advanced computing labs, and industry \nprestige that the other universities simply can't match. \nAt the end of the day, UWA’s Master of Information Technology just felt like the most natural \nnext step for me. It doesn’t waste time rehashing basic IT concepts. Instead, the modules \ndirectly hit on the exact challenges I face daily in enterprise systems—like cloud environments, \nsoftware quality engineering, and intelligent systems. It’s exactly the bridge I need to transition \nfrom writing code as a developer to designing and managing large-scale enterprise architecture. \nWhy Not Bangladesh"),
#  Document(metadata={'producer': 'macOS Version 26.5.1 (Build 25F80) Quartz PDFContext', 'creator': '', 'creationdate': "D:20260711165750Z00'00'", 'source': '../data/pdf/Sanjana_SOP_UWA_MIT_v4.pdf', 'file_path': '../data/pdf/Sanjana_SOP_UWA_MIT_v4.pdf', 'total_pages': 7, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20260711165750Z00'00'", 'trapped': '', 'modDate': "D:20260711165750Z00'00'", 'creationDate': "D:20260711165750Z00'00'", 'page': 4}, page_content='I did look into local options before going this route. BRAC University and United International \nUniversity (UIU) both offer postgraduate Computer Science programs, and I have nothing \nagainst them academically. But neither of them has a master’s program in Information \nTechnology with ACS Professional accreditation at this level, and neither can offer the \nindustry-linked, internationally benchmarked facilities that UWA provides. It is not that local \nuniversities are not good, it is just that this specific combination of
ximately AUD 5,833 in \nBangladesh, which shows that our financial foundations are here, not abroad. \nI have never left Bangladesh before. I have no relatives in Australia, no prior visa history of \nany kind, no military obligations, and no involvement in civil unrest. Going to Australia is \nabout getting an education - nothing more. Everything else in my life is here: my family, my \nproperty, my career plans, my marriage. Returning after my studies is not a condition I have \nreluctantly accepted. It is genuinely what I want to do. \nCareer Goals \nBangladesh’s technology industry is growing fast. The government’s Smart Bangladesh Vision \n2041 has placed enterprise software, cloud infrastructure, AI-driven systems, and digital \ntransformation at the center of national development, and companies are actively looking for \nprofessionals who can work across all of those layers. Right now, there is a real gap between \nwhat the market needs and what local graduates can offer — particularly in advanced software \nengineering, applied AI, and cloud-based system design. Coming back with an ACS-accredited \nmaster's from UWA will put me in a strong position to fill that gap."),
#  Document(metadata={'producer': 'macOS Version 26.5.1 (Build 25F80) Quartz PDFContext', 'creator': '', 'creationdate': "D:20260711165750Z00'00'", 'source': '../data/pdf/Sanjana_SOP_UWA_MIT_v4.pdf', 'file_path': '../data/pdf/Sanjana_SOP_UWA_MIT_v4.pdf', 'total_pages': 7, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': "D:20260711165750Z00'00'", 'trapped': '', 'modDate': "D:20260711165750Z00'00'", 'creationDate': "D:20260711165750Z00'00'", 'page': 6}, page_content='My immediate goal after returning is to step into a senior technical role — as a Software \nArchitect, Cloud Solutions Engineer, or AI-ML Engineer — at a company-like Brain Station \n23, WellDev, Therap BD, or Reve Systems. These are companies that build products at the \nintersection of enterprise software and intelligent systems, which is exactly where my UWA \ntraining will apply. IT professionals in Bangladesh with internationally accredited postgraduate \nqualifications earn between BDT 1,20,000 and 2,50,000 per month, compared to BDT 50,000 \nto 80,000 for locally trained graduates. Financially, returning home makes far more sense than \nstaying abroad. Further down the line, I want to co-found a tech company with my husband \nthat builds intelligent enterprise software for real estate, fintech, and healthcare — sectors \nwhere both of us have direct hands-on experience and where the combination of applied \ncomputing, AI, and software systems knowledge will be most valuable. My father’s \nbackground in real estate through Sydney Homes Ltd adds an additional layer of domain \nknowledge we can draw on. All of this is anchored in Bangladesh. \nVisa Conditions and Conclusion \nI understand the conditions attached to the Student Visa Subclass 500 and I will follow them. \nI will stay enrolled full-time, keep my attendance above 80%, stick to the 48-hour per fortnight \nwork limit during semesters, and maintain valid Overseas Student Health Cover (OSHC) \nthroughout my stay. I am going to Australia to study, and that is the only reason. \nI am a genuine student. I have a clear reason for this degree, real professional experience that \nmakes the course directly relevant across all three of its specialisations, three financially \ncapable sponsors, and strong personal ties to Bangladesh through my family, my property, my \nhusband’s career, and my own career plans. The Master of Information Technology at UWA \nis the right next step for me, and it is one I cannot take locally. I sincerely request that this \napplication be looked upon favorably. Thank you for your time and consideration. \n \nYours Sincerely, \nSanjana Akter Roshni \n324/A, East Rampura, Dhaka, Bangladesh \nPassport No: A21053837 \nContact: +88 01866201985 \nEmail: sa.roshni24@gmail.com')]

# %%
output_file = "../data/text_files/combined_documents.txt"

with open(output_file,"w",encoding="utf-8") as f:
    for doc in document:
        f.write(doc.page_content)
